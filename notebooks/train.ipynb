# %%
import torch
print(torch.__version__)
# Out:
# 1.4.0

# %%
import sys 
sys.path.append('../src/')
import load_transform_data
from torch.utils import data 
from torch import nn
import torch.nn.functional as F
import pandas as pd 

from my_classes import Dataset 

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# Parameters 
train_params = {'batch_size': 64, 'shuffle': True, 'num_workers': 0}
test_params = {'batch_size': 1, 'shuffle': True, 'num_workers': 0}

# Generators 
trans = load_transform_data.TransformXY()
trans.transform_data('LabelBinarizer')

train_set = Dataset(trans, 'train')
train_generator = data.DataLoader(train_set, **train_params)

test_set = Dataset(trans, 'test')
test_generator = data.DataLoader(test_set, **test_params)

# %%
# CONSTANTS
max_epochs = 300
n_feature = 64
n1_hidden = 48
n2_hidden = 48
n1_out = 8  # train_set.Y_tone.shape 
n2_out = 18 # train_set.Y_initial.shape
n3_out = 70 # train_set.Y_final.shape
p_dropout1 = 0.5
p_dropout2 = 0.5

# %%
class TeochewNet(nn.Module):
    def __init__(self, n_feature, n1_hidden, n2_hidden, n1_out, n2_out, n3_out):
        """"Constructor of the class"""
        super(TeochewNet, self).__init__()
        
        self.hidden1 = torch.nn.Linear(n_feature, n1_hidden)
        self.hidden2 = torch.nn.Linear(n1_hidden, n2_hidden)
        self.dropout1 = torch.nn.Dropout(p_dropout1)
        self.dropout2 = torch.nn.Dropout(p_dropout2)
        self.relu = nn.ReLU()
        self.out1 = torch.nn.Linear(n2_hidden, n1_out)
        self.out2 = torch.nn.Linear(n2_hidden, n2_out)
        self.out3 = torch.nn.Linear(n2_hidden, n3_out)
        
    def forward(self, x):
        x = self.hidden1(x)
        x = self.relu(x)
        x = self.dropout1(x)
        x = self.hidden2(x)
        x = self.relu(x)
        x = self.dropout2(x)
        x1 = self.out1(x)
        x2 = self.out2(x)
        x3 = self.out3(x)
        return x1.type(torch.DoubleTensor), x2.type(torch.DoubleTensor), x3.type(torch.DoubleTensor)
    
teochewnet = TeochewNet(n_feature, n1_hidden, n2_hidden, n1_out, n2_out, n3_out)
print(teochewnet)
# Out:
# TeochewNet(
#   (hidden1): Linear(in_features=64, out_features=48, bias=True)
#   (hidden2): Linear(in_features=48, out_features=48, bias=True)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (relu): ReLU()
#   (out1): Linear(in_features=48, out_features=8, bias=True)
#   (out2): Linear(in_features=48, out_features=18, bias=True)
#   (out3): Linear(in_features=48, out_features=70, bias=True)
# )

# %%
from torch.autograd import Variable
import torch.optim as optim

criterion1 = nn.CrossEntropyLoss()
criterion2 = nn.CrossEntropyLoss()
criterion3 = nn.CrossEntropyLoss()

optimizer = optim.Adam(teochewnet.parameters(), lr=0.01, weight_decay=0.01)

def categorical_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """
    max_preds = preds.argmax(dim = 1, keepdim = True) # get the index of the max probability
    correct = max_preds.squeeze(1).eq(y)
    return correct.sum() / torch.FloatTensor([y.shape[0]])

for epoch in range(max_epochs):  # loop over the dataset multiple times
    epoch_loss = 0.0
    epoch_acc = 0
    for i, (x, y_tone, y_initial, y_final) in enumerate(train_generator, 0):
        # zero the parameter gradients
        out1, out2, out3 = teochewnet(Variable(x.float()))
        loss1 = criterion1(out1, Variable(y_tone))
        loss2 = criterion2(out2, Variable(y_initial))
# [275,    10] loss: 5.829 tone acc: 0.578 initial acc: 0.484 final acc: 0.125
# [276,    10] loss: 5.904 tone acc: 0.500 initial acc: 0.531 final acc: 0.125
# [277,    10] loss: 5.928 tone acc: 0.500 initial acc: 0.453 final acc: 0.125
# [278,    10] loss: 5.893 tone acc: 0.516 initial acc: 0.422 final acc: 0.234
# [279,    10] loss: 5.780 tone acc: 0.672 initial acc: 0.516 final acc: 0.203
# [280,    10] loss: 5.936 tone acc: 0.688 initial acc: 0.438 final acc: 0.141
# [281,    10] loss: 5.890 tone acc: 0.625 initial acc: 0.469 final acc: 0.203
# [282,    10] loss: 5.803 tone acc: 0.547 initial acc: 0.422 final acc: 0.172
# [283,    10] loss: 5.956 tone acc: 0.500 initial acc: 0.406 final acc: 0.156
# [284,    10] loss: 5.930 tone acc: 0.609 initial acc: 0.422 final acc: 0.156
# [285,    10] loss: 5.874 tone acc: 0.609 initial acc: 0.391 final acc: 0.281
# [286,    10] loss: 5.852 tone acc: 0.594 initial acc: 0.406 final acc: 0.234
# [287,    10] loss: 5.885 tone acc: 0.516 initial acc: 0.484 final acc: 0.156
# [288,    10] loss: 5.948 tone acc: 0.578 initial acc: 0.500 final acc: 0.109
# [289,    10] loss: 5.985 tone acc: 0.500 initial acc: 0.625 final acc: 0.125
# [290,    10] loss: 5.882 tone acc: 0.516 initial acc: 0.547 final acc: 0.156
# [291,    10] loss: 5.933 tone acc: 0.562 initial acc: 0.609 final acc: 0.281
# [292,    10] loss: 5.900 tone acc: 0.625 initial acc: 0.500 final acc: 0.141
# [293,    10] loss: 5.872 tone acc: 0.547 initial acc: 0.516 final acc: 0.234
# [294,    10] loss: 5.880 tone acc: 0.547 initial acc: 0.531 final acc: 0.094
# [295,    10] loss: 5.882 tone acc: 0.641 initial acc: 0.406 final acc: 0.094
# [296,    10] loss: 5.833 tone acc: 0.609 initial acc: 0.406 final acc: 0.125
# [297,    10] loss: 5.990 tone acc: 0.531 initial acc: 0.422 final acc: 0.188
# [298,    10] loss: 5.929 tone acc: 0.484 initial acc: 0.547 final acc: 0.156
# [299,    10] loss: 5.830 tone acc: 0.609 initial acc: 0.391 final acc: 0.172
# [300,    10] loss: 5.903 tone acc: 0.625 initial acc: 0.469 final acc: 0.156
# Finished Training

# %%
c_tones = trans.encT.classes_
c_initials = trans.encI.classes_
c_finals = trans.encF.classes_

# %%
c_initials
# Out:
# array([' ', 'b', 'g', 'h', 'k', 'kʰ', 'l', 'm', 'n', 'p', 'pʰ', 's', 't',
#        'ts', 'tsʰ', 'tʰ', 'z', 'ŋ'], dtype='<U3')

# %%
# Test the model

results = []

teochewnet.eval()
with torch.no_grad():
    tone_correct, initial_correct, final_correct = 0, 0, 0
    tone_total, initial_total, final_total = 0, 0, 0
    for _, (x, y_tone, y_initial, y_final) in enumerate(test_generator, 0):
        out1, out2, out3 = teochewnet(Variable(x.float()))
        _, tone_pred = torch.max(out1, 1)
        _, initial_pred = torch.max(out2, 1)
        _, final_pred = torch.max(out3, 1)
        row = [c_tones[tone_pred], c_initials[initial_pred], c_finals[final_pred]]
        row = row + [c_tones[y_tone], c_initials[y_initial], c_finals[y_final]]
        results.append(row)
        tone_total += y_tone.size(0)
        initial_total += y_initial.size(0)
        final_total += y_final.size(0)
        tone_correct += (tone_pred == y_tone).sum().item()
        initial_correct += (initial_pred == y_initial).sum().item()
        final_correct += (final_pred == y_final).sum().item() 
    
    print('tone acc: {}%, inital acc: {}%, final acc: {}%'.format(100*tone_correct/tone_total, \
                                                                 100*initial_correct/initial_total, \
                                                                 100*final_correct/final_total))
# Out:
# tone acc: 58.38509316770186%, inital acc: 59.006211180124225%, final acc: 18.012422360248447%

# %%
cols = ['pred_citation', 'pred_initial', 'pred_final', 'citation', 'initial', 'final']
result_df = pd.DataFrame(results, columns=cols)

# %%
result_df.sample(30)
# Out:
#     pred_citation pred_initial pred_final citation initial final
# 37             33           tʰ          o       21      tʰ    oʔ
# 97            213            p         ou      213      pʰ    ue
# 132            53                     ĩã∼       53            uŋ
# 140            33            s          i       21       s   ueʔ
# 59             35                      iu        4       g   ueʔ
# 141            55            l         ou      213       l    iu
# 96             33            t          u        4       t   ieʔ
# 113            33           tʰ          o       21      tʰ    ik
# 149           213            k         ɯŋ      213      kʰ    ɯŋ
# 39            213            p          i       21       p   iaʔ
# 48             33                       u       21           iak
# 7              55                      aŋ       55       h   ũẽ∼
# 123            55                     ĩẽ∼       55           ĩẽ∼
# 14             55            m         uŋ       55       m    oŋ
# 64              4            m          i       35       l    ai
# 5               4                       e       21            ak
# 131            55            k         ue        4      kʰ    ak
# 50             33           ts         eŋ       33      ts    am
# 16             53            s          u       21       s    oʔ
# 160            53            s          i       53      ts    ui
# 43             55            l         aŋ       33       l    aŋ
# 29             33            t         aŋ       33      ts    oŋ
# 146            53            h         ɯŋ      213       h    am
# 82             53            b         ou       53          [[]]
# 112            33            s          o       33           iəu
# 65             53           ts         ɯŋ       35      ts  [[]]
# 105           213            k         ai      213       k    ai
# 135            53            k         ɯŋ       33       k    ã∼
# 159            33            k         ou       33       k    ui
# 150            55            t         ɯŋ       55       t    aŋ

# %%
result_df[result_df['final']==result_df['pred_final']]
# Out:
#     pred_citation pred_initial pred_final citation initial final
# 0              33            k         ou       33      kʰ    ou
# 9              55            l         aŋ       55       l    aŋ
# 13            213            p         aŋ      213       p    aŋ
# 26             55            p         ue       55       p    ue
# 32            213           kʰ         ou      213      kʰ    ou
# 36             55            l          o       55       l     o
# 43             55            l         aŋ       33       l    aŋ
# 45             53            t        iəu       55       h   iəu
# 61             55            k         iu       55       k    iu
# 62             55            l         aŋ       55       l    aŋ
# 69             33            t         eŋ       33       t    eŋ
# 74             53            l          i       55       n     i
# 75            213            t          i       35       t     i
# 85             53            h         ou       53       p    ou
# 88             53            b          e       53       b     e
# 89             55            t        iəu       11       l   iəu
# 95             55            h          u       55       h     u
# 105           213            k         ai      213       k    ai
# 106            33           ts          i       33       t     i
# 107           213            p         ou       35      pʰ    ou
# 115            55            l         ou       55       l    ou
# 122            53            l          i       53       l     i
# 123            55                     ĩẽ∼       55           ĩẽ∼
# 137           213           tʰ          i      213      tʰ     i
# 144           213           tʰ          o      213      tʰ     o
# 148            33            p         aŋ       33       p    aŋ
# 149           213            k         ɯŋ      213      kʰ    ɯŋ
# 155           213           tʰ         ɯŋ      213      tʰ    ɯŋ
# 156           213            s         ɯŋ      213       s    ɯŋ

# %%
trans.teochew_df['citation_teo'] = trans.teochew_df['citation_teo'].astype(str)
result_df[cols] = result_df[cols].astype(str)

# %%
merged_pd = pd.merge(trans.teochew_df, result_df, how='left', left_on=['citation_teo','initial_teo','final_teo'], \
         right_on = ['citation', 'initial', 'final'])
merged_pd[(merged_pd['pred_citation'].notnull())&(merged_pd['pred_final'].notnull())].sample(30)
# Out:
#     BENZI_IN_SOURCE_teo citation_teo initial_teo final_teo pred_citation  \
# 397                   帽           11           b         o             4
# 325                   鱗           55           l        aŋ            55
# 517                   月            4           g       ueʔ            35
# 542                   簿           35          pʰ        ou           213
# 802                   渣           33          ts         a            33
# 317                   電           35           t       ieŋ           213
# 210                   行           55           h        aŋ            55
# 252                   聾           55           l        aŋ            55
# 299                   生           33           s        ẽ∼            33
# 305                   爸           33           p         a             4
# 413                   蓋          213           k        ai           213
# 139                   高           33           k         o            33
# 309                   丈           53           t       ĩẽ∼           213
# 269                   做          213          ts         o           213
# 65                    水           53          ts        ui            53
# 79                    拍           21          pʰ        aʔ            33
# 727                   許           53           h         ɯ            53
# 599                   蘭           33           l        aŋ            55
# 718                   褪          213          tʰ        ɯŋ           213
# 286                   缸           33           k        ɯŋ            33
# 111                   光           33           k        ɯŋ            33
# 387                   媽           53           m         a            53
# 350                   冰           33           p       ĩã∼            33
# 526                   騾           55           l         o            55
# 789                   窗           33          tʰ        eŋ            33
# 783                   輦           53           l        iŋ            53
# 93                    盲           55           m         e             4
# 213                   料           11           l       iəu            55
# 660                   嚏          213          tʰ         i           213
# 211                   內           35           l        ai             4
#
#     pred_initial pred_final citation initial final
# 397            m          e       11       b     o
# 325            l         aŋ       55       l    aŋ
# 517                      iu        4       g   ueʔ
# 542            p         ou       35      pʰ    ou
# 802            t         ou       33      ts     a
# 317            t         ɯŋ       35       t   ieŋ
# 210                      iŋ       55       h    aŋ
# 252            l         aŋ       55       l    aŋ
# 299            s         uŋ       33       s    ẽ∼
# 305            p         ak       33       p     a
# 413            k         ai      213       k    ai
# 139            k         ou       33       k     o
# 309            t         ɯŋ       53       t   ĩẽ∼
# 269           ts         ai      213      ts     o
# 65             s          i       53      ts    ui
# 79             p          o       21      pʰ    aʔ
# 727            s          u       53       h     ɯ
# 599            l         aŋ       33       l    aŋ
# 718           tʰ         ɯŋ      213      tʰ    ɯŋ
# 286            k        ũã∼       33       k    ɯŋ
# 111            k        ũã∼       33       k    ɯŋ
# 387                       e       53       m     a
# 350            p         aŋ       33       p   ĩã∼
# 526            l          o       55       l     o
# 789            s         ɯŋ       33      tʰ    eŋ
# 783            n          i       53       l    iŋ
# 93                        i       55       m     e
# 213            t        iəu       11       l   iəu
# 660           tʰ          i      213      tʰ     i
# 211            m          i       35       l    ai
